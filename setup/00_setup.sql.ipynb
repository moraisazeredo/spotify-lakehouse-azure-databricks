# %%
# %sql
CREATE CATALOG IF NOT EXISTS spotify

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS spotify.landing;

CREATE EXTERNAL VOLUME spotify.landing.spotify_resource
LOCATION 'abfss://uc-ext-azure@daatalake.dfs.core.windows.net/spotify/resource';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS spotify.bronze
MANAGED LOCATION 'abfss://uc-ext-azure@daatalake.dfs.core.windows.net/spotify/bronze';

CREATE SCHEMA IF NOT EXISTS spotify.silver
MANAGED LOCATION 'abfss://uc-ext-azure@daatalake.dfs.core.windows.net/spotify/silver';

CREATE SCHEMA IF NOT EXISTS spotify.gold
MANAGED LOCATION 'abfss://uc-ext-azure@daatalake.dfs.core.windows.net/spotify/gold';
